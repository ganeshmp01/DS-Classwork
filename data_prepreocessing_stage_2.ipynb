# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshmp01/DS-Classwork/blob/main/data_prepreocessing_stage_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/ganeshmp01/Datascience-Batch-22/main/13.%20Data%20Preprocessing/Data/companytest.csv")
df.head()
# Out:
#   Company    Age     Salary
# 0       b   40.0  9000000.0
# 1       d  300.0     1000.0
# 2       a   30.0     -400.0
# 3     'a'   20.0        NaN
# 4       c   30.0        NaN

# %%
df.isna().sum()
# Out:
# Company    3
# Age        4
# Salary     7
# dtype: int64

# %%
import statistics as st

# %%
mode_val=st.mode(df['Company'])
mode_val
# Out:
# 'b'

# %%
df['Company'].value_counts()
# Out:
# b      9
# a      9
# c      8
# 'a'    2
# d      1
# 'c'    1
# Name: Company, dtype: int64

# %%
df['Age']=df['Age'].fillna(df['Age'].median())

# %%
df['Age'].describe()
# Out:
# count     33.000000
# mean      39.939394
# std       47.426878
# min       18.000000
# 25%       23.000000
# 50%       34.000000
# 75%       37.000000
# max      300.000000
# Name: Age, dtype: float64

# %%
df['Age']
# Out:
# 0      40.0
# 1     300.0
# 2      30.0
# 3      20.0
# 4      30.0
# 5      35.0
# 6      40.0
# 7      23.0
# 8      34.0
# 9      34.0
# 10     23.0
# 11     34.0
# 12     45.0
# 13     23.0
# 14     34.0
# 15     45.0
# 16     18.0
# 17     40.0
# 18     23.0
# 19     23.0
# 20     34.0
# 21     22.0
# 22     32.0
# 23     37.0
# 24     50.0
# 25     21.0
# 26     34.0
# 27     34.0
# 28     23.0
# 29     34.0
# 30     45.0
# 31     23.0
# 32     35.0
# Name: Age, dtype: float64

# %%
df['Age'].loc[(df['Age'] > 60) | (df['Age'] < 18)] = np.nan
# Out:
# <ipython-input-11-f68fd9bdd8ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].loc[(df['Age'] > 60) | (df['Age'] < 18)] = np.nan

# %%
df['Age']
# Out:
# 0     40.0
# 1      NaN
# 2     30.0
# 3     20.0
# 4     30.0
# 5     35.0
# 6     40.0
# 7     23.0
# 8     34.0
# 9     34.0
# 10    23.0
# 11    34.0
# 12    45.0
# 13    23.0
# 14    34.0
# 15    45.0
# 16    18.0
# 17    40.0
# 18    23.0
# 19    23.0
# 20    34.0
# 21    22.0
# 22    32.0
# 23    37.0
# 24    50.0
# 25    21.0
# 26    34.0
# 27    34.0
# 28    23.0
# 29    34.0
# 30    45.0
# 31    23.0
# 32    35.0
# Name: Age, dtype: float64

# %%
df['Salary']=df['Salary'].fillna(df['Salary'].median())

# %%
df['Salary'].head()
# Out:
# 0    9000000.0
# 1       1000.0
# 2       -400.0
# 3       4412.0
# 4       4412.0
# Name: Salary, dtype: float64

# %%
df['Salary'].describe()
# Out:
# count    3.300000e+01
# mean     2.771126e+05
# std      1.565914e+06
# min     -4.000000e+02
# 25%      3.000000e+03
# 50%      4.412000e+03
# 75%      6.000000e+03
# max      9.000000e+06
# Name: Salary, dtype: float64

# %%
df['Salary'].loc[df['Salary'] < 0 ]=np.nan
# Out:
# <ipython-input-16-90b34ffe4e81>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salary'].loc[df['Salary'] < 0 ]=np.nan

# %%
df.head()
# Out:
#   Company   Age     Salary
# 0       b  40.0  9000000.0
# 1       d   NaN     1000.0
# 2       a  30.0        NaN
# 3     'a'  20.0     4412.0
# 4       c  30.0     4412.0

# %%
df['Company'] = df['Company'].fillna("Not Specified")

# %%
df['Company']
# Out:
# 0                 b
# 1                 d
# 2                 a
# 3               'a'
# 4                 c
# 5               'a'
# 6                 c
# 7                 a
# 8                 c
# 9                 a
# 10              'c'
# 11                a
# 12                b
# 13                b
# 14                b
# 15                b
# 16                b
# 17    Not Specified
# 18                a
# 19                c
# 20                a
# 21    Not Specified
# 22                c
# 23                a
# 24                c
# 25                a
# 26                c
# 27    Not Specified
# 28                c
# 29                a
# 30                b
# 31                b
# 32                b
# Name: Company, dtype: object

# %%
df['Company'] = df['Company'].apply(lambda x: x.replace("'", ''))

# %%
df['Company']
# Out:
# 0                 b
# 1                 d
# 2                 a
# 3                 a
# 4                 c
# 5                 a
# 6                 c
# 7                 a
# 8                 c
# 9                 a
# 10                c
# 11                a
# 12                b
# 13                b
# 14                b
# 15                b
# 16                b
# 17    Not Specified
# 18                a
# 19                c
# 20                a
# 21    Not Specified
# 22                c
# 23                a
# 24                c
# 25                a
# 26                c
# 27    Not Specified
# 28                c
# 29                a
# 30                b
# 31                b
# 32                b
# Name: Company, dtype: object

# %%
df['Company'].mode()
# Out:
# 0    a
# Name: Company, dtype: object

# %%
df['Company']=df['Company'].apply(lambda x: x.replace("Not Specified",df['Company'].mode()[0]))

# %%
df['Company']
# Out:
# 0     b
# 1     d
# 2     a
# 3     a
# 4     c
# 5     a
# 6     c
# 7     a
# 8     c
# 9     a
# 10    c
# 11    a
# 12    b
# 13    b
# 14    b
# 15    b
# 16    b
# 17    a
# 18    a
# 19    c
# 20    a
# 21    a
# 22    c
# 23    a
# 24    c
# 25    a
# 26    c
# 27    a
# 28    c
# 29    a
# 30    b
# 31    b
# 32    b
# Name: Company, dtype: object

# %%
df.isna().sum()
# Out:
# Company    0
# Age        1
# Salary     1
# dtype: int64

# %%
df['Age']=df['Age'].fillna(df['Age'].median())

# %%
df['Salary']=df['Salary'].fillna(df['Salary'].median())

# %%
df.isna().sum()
# Out:
# Company    0
# Age        0
# Salary     0
# dtype: int64

# %%
df
# Out:
#    Company   Age     Salary
# 0        b  40.0  9000000.0
# 1        d  34.0     1000.0
# 2        a  30.0     4412.0
# 3        a  20.0     4412.0
# 4        c  30.0     4412.0
# 5        a  35.0     2300.0
# 6        c  40.0     3000.0
# 7        a  23.0     4000.0
# 8        c  34.0     5000.0
# 9        a  34.0     6000.0
# 10       c  23.0     7000.0
# 11       a  34.0     8000.0
# 12       b  45.0     9000.0
# 13       b  23.0     4412.0
# 14       b  34.0     1089.0
# 15       b  45.0     4412.0
# 16       b  18.0     1234.0
# 17       a  40.0     3000.0
# 18       a  23.0     3000.0
# 19       c  23.0     3030.0
# 20       a  34.0     5000.0
# 21       a  22.0     4412.0
# 22       c  32.0     4412.0
# 23       a  37.0     3045.0
# 24       c  50.0     3184.0
# 25       a  21.0     4824.0
# 26       c  34.0     5835.0
# 27       a  34.0     7084.0
# 28       c  23.0     8943.0
# 29       a  34.0     8345.0
# 30       b  45.0     9284.0
# 31       b  23.0     4412.0
# ...

# %% [markdown]
# Handling Outliers

# %%
num_cols=df.select_dtypes(include =np.number).columns[:]
num_cols
# Out:
# Index(['Age', 'Salary'], dtype='object')

# %%
for col_name in num_cols:
  print(col_name)
  q1 = df[col_name].quantile(0.25)
  q3 = df[col_name].quantile(0.75)
  iqr= q3-q1
  print("The value of q1 :" , q1)
  print("The value of q3 :" , q3)
  print("IQR",iqr)
  lower=q1-(1.5*iqr)
  upper=q3+(1.5*iqr)
  if col_name == 'Age':
        lower = 18
  if col_name == 'Salary':
        lower = 1000.0
  print("Lower limit",lower)
  print("Upper limit",upper)
# Out:
# Age
# The value of q1 : 23.0
# The value of q3 : 35.0
# IQR 12.0
# Lower limit 18
# Upper limit 53.0
# Salary
# The value of q1 : 3030.0
# The value of q3 : 6000.0
# IQR 2970.0
# Lower limit 1000.0
# Upper limit 10455.0

# %%
df['Salary'].describe()
# Out:
# count    3.300000e+01
# mean     2.772584e+05
# std      1.565887e+06
# min      1.000000e+03
# 25%      3.030000e+03
# 50%      4.412000e+03
# 75%      6.000000e+03
# max      9.000000e+06
# Name: Salary, dtype: float64

# %%
df['Age'].describe()
# Out:
# count    33.000000
# mean     31.878788
# std       8.361958
# min      18.000000
# 25%      23.000000
# 50%      34.000000
# 75%      35.000000
# max      50.000000
# Name: Age, dtype: float64

# %%
import seaborn as sns

# %%
sns.catplot(data=df,kind='box', x='Age')

# %%
sns.catplot(data=df,kind='box', x='Salary')

# %% [markdown]
# #Encoding - Process of transforming information in one form to another

# %% [markdown]
# Data Encoding is an important pre-processing step in Machine Learning. It refers to the process of converting categorical or textual data into numerical format, so that it can be used as input for algorithms to process. The reason for encoding is that most machine learning algorithms work with numbers and not with text or categorical variables.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,StandardScaler,MinMaxScaler

# %%
pip install category_encoders

# %%
import category_encoders as ce

# %% [markdown]
# • A binary Column is created for each Unique Category in the variable.
#
# • If a category is present in a sample, the corresponding column is set to 1, and all other columns are set to 0.

# %% [markdown]
# One-Hot Encoding — N categories in a variable, N binary variables.

# %%
one_hot = pd.get_dummies(df['Company'])

# %%
one_hot
# Out:
#     a  b  c  d
# 0   0  1  0  0
# 1   0  0  0  1
# 2   1  0  0  0
# 3   1  0  0  0
# 4   0  0  1  0
# 5   1  0  0  0
# 6   0  0  1  0
# 7   1  0  0  0
# 8   0  0  1  0
# 9   1  0  0  0
# 10  0  0  1  0
# 11  1  0  0  0
# 12  0  1  0  0
# 13  0  1  0  0
# 14  0  1  0  0
# 15  0  1  0  0
# 16  0  1  0  0
# 17  1  0  0  0
# 18  1  0  0  0
# 19  0  0  1  0
# 20  1  0  0  0
# 21  1  0  0  0
# 22  0  0  1  0
# 23  1  0  0  0
# 24  0  0  1  0
# 25  1  0  0  0
# 26  0  0  1  0
# 27  1  0  0  0
# 28  0  0  1  0
# 29  1  0  0  0
# 30  0  1  0  0
# 31  0  1  0  0
# 32  0  1  0  0

# %% [markdown]
# Dummy encoding — N categories in a variable, N-1 binary variables.

# %%
dummy_df = pd.get_dummies(df['Company'], drop_first=True, prefix='Company')

# %%
dummy_df
# Out:
#     Company_b  Company_c  Company_d
# 0           1          0          0
# 1           0          0          1
# 2           0          0          0
# 3           0          0          0
# 4           0          1          0
# 5           0          0          0
# 6           0          1          0
# 7           0          0          0
# 8           0          1          0
# 9           0          0          0
# 10          0          1          0
# 11          0          0          0
# 12          1          0          0
# 13          1          0          0
# 14          1          0          0
# 15          1          0          0
# 16          1          0          0
# 17          0          0          0
# 18          0          0          0
# 19          0          1          0
# 20          0          0          0
# 21          0          0          0
# 22          0          1          0
# 23          0          0          0
# 24          0          1          0
# ...

# %%
from sklearn.preprocessing import LabelEncoder as le

# %%
df['Company']=df['Company'].astype('category')

# %%
df['Company'].cat.codes
# Out:
# 0     1
# 1     3
# 2     0
# 3     0
# 4     2
# 5     0
# 6     2
# 7     0
# 8     2
# 9     0
# 10    2
# 11    0
# 12    1
# 13    1
# 14    1
# 15    1
# 16    1
# 17    0
# 18    0
# 19    2
# 20    0
# 21    0
# 22    2
# 23    0
# 24    2
# 25    0
# 26    2
# 27    0
# 28    2
# 29    0
# 30    1
# 31    1
# 32    1
# dtype: int8

# %%
label_encoder = LabelEncoder()
df['Company_encoded'] = label_encoder.fit_transform(df['Company'])

# %%
df['Company_encoded']
# Out:
# 0     1
# 1     3
# 2     0
# 3     0
# 4     2
# 5     0
# 6     2
# 7     0
# 8     2
# 9     0
# 10    2
# 11    0
# 12    1
# 13    1
# 14    1
# 15    1
# 16    1
# 17    0
# 18    0
# 19    2
# 20    0
# 21    0
# 22    2
# 23    0
# 24    2
# 25    0
# 26    2
# 27    0
# 28    2
# 29    0
# 30    1
# 31    1
# 32    1
# Name: Company_encoded, dtype: int64

# %% [markdown]
# Leave-One-Out Encoding (LOO Encoding) is a method that encodes each category in a categorical variable by calculating the mean of the target variable, excluding the current data point, which belongs to that category.

# %%
cat = category_encoders.LeaveOneOutEncoder()

# %%
cat.fit_transform(df[['Company']],df['Salary'])
# Out:
#          Company
# 0   4.484625e+03
# 1   2.772584e+05
# 2   4.878615e+03
# 3   4.878615e+03
# 4   5.050500e+03
# 5   5.041077e+03
# 6   5.227000e+03
# 7   4.910308e+03
# 8   4.977000e+03
# 9   4.756462e+03
# 10  4.727000e+03
# 11  4.602615e+03
# 12  1.128360e+06
# 13  1.128933e+06
# 14  1.129348e+06
# 15  1.128933e+06
# 16  1.129330e+06
# 17  4.987231e+03
# 18  4.987231e+03
# 19  5.223250e+03
# 20  4.833385e+03
# 21  4.878615e+03
# 22  5.050500e+03
# 23  4.983769e+03
# 24  5.204000e+03
# 25  4.846923e+03
# 26  4.872625e+03
# 27  4.673077e+03
# 28  4.484125e+03
# 29  4.576077e+03
# 30  1.128324e+06
# 31  1.128933e+06
# 32  1.129230e+06

# %% [markdown]
# ### **Transforming Numerical Variables..**

# %% [markdown]
# #Standardisation / #Scaling :
# Many machine learning algorithms work better when features are on a relatively similar scale and close to normally distributed. MinMaxScaler, RobustScaler, StandardScaler, and Normalizer are scikit-learn methods to preprocess data for machine learning

# %% [markdown]
# Many machine learning algorithms perform better or converge faster when features are on a relatively similar scale and/or close to normally distributed.

# %% [markdown]
# Scaling and standardizing can help features arrive in more digestible form for these algorithms.

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
df
# Out:
#    Company   Age     Salary  Company_encoded
# 0        b  40.0  9000000.0                1
# 1        d  34.0     1000.0                3
# 2        a  30.0     4412.0                0
# 3        a  20.0     4412.0                0
# 4        c  30.0     4412.0                2
# 5        a  35.0     2300.0                0
# 6        c  40.0     3000.0                2
# 7        a  23.0     4000.0                0
# 8        c  34.0     5000.0                2
# 9        a  34.0     6000.0                0
# 10       c  23.0     7000.0                2
# 11       a  34.0     8000.0                0
# 12       b  45.0     9000.0                1
# 13       b  23.0     4412.0                1
# 14       b  34.0     1089.0                1
# 15       b  45.0     4412.0                1
# 16       b  18.0     1234.0                1
# 17       a  40.0     3000.0                0
# 18       a  23.0     3000.0                0
# 19       c  23.0     3030.0                2
# ...

# %%
ss = StandardScaler()

# %%
df['Age'] = df['Age'].astype('float')

# %%
scaled_columns = ss.fit_transform(df[['Salary','Age']])

# %%
scaled_columns
# Out:
# array([[ 5.6568483 ,  0.98626775],
#        [-0.17915833,  0.25760725],
#        [-0.17694559, -0.22816642],
#        [-0.17694559, -1.44260059],
#        [-0.17694559, -0.22816642],
#        [-0.17831526,  0.37905066],
#        [-0.1778613 ,  0.98626775],
#        [-0.17721278, -1.07827034],
#        [-0.17656426,  0.25760725],
#        [-0.17591574,  0.25760725],
#        [-0.17526723, -1.07827034],
#        [-0.17461871,  0.25760725],
#        [-0.17397019,  1.59348483],
#        [-0.17694559, -1.07827034],
#        [-0.17910061,  0.25760725],
#        [-0.17694559,  1.59348483],
#        [-0.17900658, -1.68548742],
#        [-0.1778613 ,  0.98626775],
#        [-0.1778613 , -1.07827034],
#        [-0.17784184, -1.07827034],
#        [-0.17656426,  0.25760725],
#        [-0.17694559, -1.19971375],
#        [-0.17694559,  0.01472041],
#        [-0.17783211,  0.6219375 ],
#        [-0.17774197,  2.20070192],
#        [-0.1766784 , -1.32115717],
#        [-0.17602275,  0.25760725],
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mm_scaler = MinMaxScaler()

# %%
scaled_colum=mm_scaler.fit_transform(df[['Salary','Age']])
scaled_colum
# Out:
# array([[1.00000000e+00, 6.87500000e-01],
#        [0.00000000e+00, 5.00000000e-01],
#        [3.79153239e-04, 3.75000000e-01],
#        [3.79153239e-04, 6.25000000e-02],
#        [3.79153239e-04, 3.75000000e-01],
#        [1.44460496e-04, 5.31250000e-01],
#        [2.22246916e-04, 6.87500000e-01],
#        [3.33370374e-04, 1.56250000e-01],
#        [4.44493833e-04, 5.00000000e-01],
#        [5.55617291e-04, 5.00000000e-01],
#        [6.66740749e-04, 1.56250000e-01],
#        [7.77864207e-04, 5.00000000e-01],
#        [8.88987665e-04, 8.43750000e-01],
#        [3.79153239e-04, 1.56250000e-01],
#        [9.88998778e-06, 5.00000000e-01],
#        [3.79153239e-04, 8.43750000e-01],
#        [2.60028892e-05, 0.00000000e+00],
#        [2.22246916e-04, 6.87500000e-01],
#        [2.22246916e-04, 1.56250000e-01],
#        [2.25580620e-04, 1.56250000e-01],
#        [4.44493833e-04, 5.00000000e-01],
#        [3.79153239e-04, 1.25000000e-01],
#        [3.79153239e-04, 4.37500000e-01],
# ...
